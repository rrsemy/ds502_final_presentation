# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import csv
from scipy.stats import linregress

# %%
def graph(var):
    x = df[var]
    y = df["Yield"]

    sns.regplot(
        x=var,
        y="Yield",
        data=df,
        scatter_kws={"s": 10, "alpha": 0.5},
        line_kws={"color": "red"}
    )

    from scipy.stats import linregress
    import matplotlib.pyplot as plt

    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    r2 = r_value**2

    plt.text(
        0.05, 0.95,
        f"$R^2 = {r2:.3f}$",
        transform=plt.gca().transAxes,
        fontsize=12,
        verticalalignment='top'
    )

    plt.show()

# %%
graph("Growth_Cycle")
graph("Sunlight_Hours")
graph("Precipitation")
graph("Average_Temperature")
graph("Drought_Days")
graph("Flood_Days")
graph("Soil_Moisture")
graph("Soil_pH")
graph("CO2_Concentration")
graph("Harvest_Year")
